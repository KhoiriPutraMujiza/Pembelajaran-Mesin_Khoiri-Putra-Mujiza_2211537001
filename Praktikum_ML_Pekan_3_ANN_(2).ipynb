# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoiriPutraMujiza/Pembelajaran-Mesin_Khoiri-Putra-Mujiza_2211537001/blob/main/Praktikum_ML_Pekan_3_ANN_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from itertools import product

# %%
# set the param
plt.rc('figure', autolayout=True)
plt.rc('image', cmap='magma')

# %% [markdown]
# kernel: Matriks 3x3 yang digunakan untuk deteksi sisi dalam konvolusi. Ini menekankan sisi dengan menyorot perbedaan nilai pixel.

# %%
# define the kernel
kernel = tf.constant([[-1, -1, -1],
                    [-1,  8, -1],
                    [-1, -1, -1],
                   ])

# %% [markdown]
# Load Gambar

# %%
# load the image
image = tf.io.read_file('fotoh.jpeg')
image = tf.io.decode_jpeg(image, channels=1)
image = tf.image.resize(image, size=[300, 300])

# %% [markdown]
# menampilkan gambar

# %%
# plot the image
img = tf.squeeze(image).numpy()
plt.figure(figsize=(5, 5))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('Original Gray Scale image')
plt.show();

# %% [markdown]
# Memformat Ulang Gambar dan Kernel untuk Konvolusi Mengonversi gambar menjadi tipe float32 Menambahkan dimensi batch ke tensor gambar (diperlukan untuk fungsi konvolusi). Membentuk ulang kernel agar cocok dengan fungsi konvolusi Casts the kernel to float32 type.

# %%
# Reformat
image = tf.image.convert_image_dtype(image, dtype=tf.float32)
image = tf.expand_dims(image, axis=0)
kernel = tf.reshape(kernel, [*kernel.shape, 1, 1])
kernel = tf.cast(kernel, dtype=tf.float32)

# %% [markdown]
# Menerapkan Lapisan Konvolusi

# %%
# convolution layer
conv_fn = tf.nn.conv2d

image_filter = conv_fn(
    input=image,
    filters=kernel,
    strides=1, # or (1, 1)
    padding='SAME',
)

plt.figure(figsize=(15, 5))

# %% [markdown]
# Menampilkan gambar konvolusi

# %%
# Plot the convolved image
plt.subplot(1, 3, 1)

plt.imshow(
    tf.squeeze(image_filter)
)
plt.axis('off')
plt.title('Convolution')
# Out:
# Text(0.5, 1.0, 'Convolution')

# %% [markdown]
# Menerapkan layer ReLu

# %%
# activation layer
relu_fn = tf.nn.relu

# Image detection
image_detect = relu_fn(image_filter)

plt.subplot(1, 3, 2)
plt.imshow(
    # Reformat for plotting
    tf.squeeze(image_detect)
)

plt.axis('off')
plt.title('Activation')
# Out:
# Text(0.5, 1.0, 'Activation')

# %% [markdown]
# Menerapkan layer pooling

# %%
# Pooling layer
pool = tf.nn.pool
image_condense = pool(input=image_detect,
                             window_shape=(2, 2),
                             pooling_type='MAX',
                             strides=(2, 2),
                             padding='SAME',
                            )

plt.subplot(1, 3, 3)
plt.imshow(tf.squeeze(image_condense))
plt.axis('off')
plt.title('Pooling')
plt.show()
